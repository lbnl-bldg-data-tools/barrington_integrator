# %%
import pandas as pd
import numpy as np

# %%
barrgrn = pd.read_csv("barrgrn.csv")
barrred = pd.read_csv("barrred.csv")
barrblue = pd.read_csv("barrblue.csv")
barrwhite = pd.read_csv("barrwhite.csv")

# %%
appended = barrgrn['UNITS'].append(barrred['UNITS']).append(barrblue['UNITS']).append(barrwhite['UNITS'])

# %%
appended = pd.DataFrame(pd.Series(appended.unique()).dropna(), columns=['first'])

# %%
appended
# Out:
#         first
# 0       Deg F
# 1        PSIG
# 2      Counts
# 3      Status
# 4     Command
# 5     MINUTES
# 6     Minutes
# 7         FPM
# 8       VOLTS
# 9       ' W.C
# 10   PSI X0.1
# 11   DEG REST
# 12      Hertz
# 13   OPEN VLV
# 14      HOURS
# 15   VDC x 10
# 16         Hz
# 17     % OPEN
# 18   Hz RESET
# 19     % F.S.
# 20     ' W.C.
# 21      Deg C
# 22       OPEN
# 23   Command$
# 24      DEG F
# 25   'w.c*.01
# 26     status
# 27   # BLOWER
# 29     P.S.I.
# 30   STEP NO.
# ..        ...
# 139  'w.c *.1
# 140       MWH
# 141  LEAD BLR
# 142      129A
# 143      GALS
# 144     'w.c.
# 145  'W.C*.01
# 146      FEET
# 147       CFM
# 148      ' Hg
# 149       MPS
# 150  'w.cX.01
# 151        pH
# 152  %HOTDECK
# 153       'WC
# 154       'wc
# 155  BLR. NO.
# 156  INCH.H2O
# 157  INCH.H20
# 158         -
# 159  INCH/SEC
# 160     ' w.c
# 161  % RECIRC
# 162  Volt Out
# 163     Volts
# 164  *.01 w.c
# 165     % R/A
# 166    Deg. F
# 167  GALx1000
# 168  PTCL/FT3
#
# ...

# %%
appended[appended['first'].str.contains('[a-zA-Z]')]
# Out:
#         first
# 0       Deg F
# 1        PSIG
# 2      Counts
# 3      Status
# 4     Command
# 5     MINUTES
# 6     Minutes
# 7         FPM
# 8       VOLTS
# 9       ' W.C
# 10   PSI X0.1
# 11   DEG REST
# 12      Hertz
# 13   OPEN VLV
# 14      HOURS
# 15   VDC x 10
# 16         Hz
# 17     % OPEN
# 18   Hz RESET
# 19     % F.S.
# 20     ' W.C.
# 21      Deg C
# 22       OPEN
# 23   Command$
# 24      DEG F
# 25   'w.c*.01
# 26     status
# 27   # BLOWER
# 29     P.S.I.
# 30   STEP NO.
# ..        ...
# 138      VOLT
# 139  'w.c *.1
# 140       MWH
# 141  LEAD BLR
# 142      129A
# 143      GALS
# 144     'w.c.
# 145  'W.C*.01
# 146      FEET
# 147       CFM
# 148      ' Hg
# 149       MPS
# 150  'w.cX.01
# 151        pH
# 152  %HOTDECK
# 153       'WC
# 154       'wc
# 155  BLR. NO.
# 156  INCH.H2O
# 157  INCH.H20
# 159  INCH/SEC
# 160     ' w.c
# 161  % RECIRC
# 162  Volt Out
# 163     Volts
# 164  *.01 w.c
# 165     % R/A
# 166    Deg. F
# 167  GALx1000
# 168  PTCL/FT3
#
# ...

# %%
appended
# Out:
# Empty DataFrame
# Columns: [first]
# Index: []
